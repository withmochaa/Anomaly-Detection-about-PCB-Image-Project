# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import PIL
import shutil

# %%
import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import tensorflow as tf

# %%
base_dir='C:\Data\switch_detection'
train_dir=os.path.join(base_dir,'train')
validation_dir=os.path.join(base_dir,'validation')
test_dir=os.path.join(base_dir,'test')

# %%
train_normal_dir=os.path.join(train_dir,'normal')
train_adnormal_dir=os.path.join(train_dir,'adnormal')
print(train_normal_dir,train_adnormal_dir)
# Out:
# C:\Data\switch_detection\train\normal C:\Data\switch_detection\train\adnormal

# %%
validation_normal_dir=os.path.join(validation_dir,'normal')
validation_adnormal_dir=os.path.join(validation_dir,'adnormal')
print(validation_normal_dir,validation_adnormal_dir)
# Out:
# C:\Data\switch_detection\validation\normal C:\Data\switch_detection\validation\adnormal

# %%
test_normal_dir=os.path.join(test_dir,'normal')
test_adnormal_dir=os.path.join(test_dir,'adnormal')
print(test_normal_dir,test_adnormal_dir)
# Out:
# C:\Data\switch_detection\test\normal C:\Data\switch_detection\test\adnormal

# %%
train_normal_fnames=os.listdir(train_normal_dir)
train_adnormal_fnames=os.listdir(train_adnormal_dir)
print(train_normal_fnames)
print(train_adnormal_fnames)
# Out:
# ['KakaoTalk_20220928_200057543.jpg', 'KakaoTalk_20220928_200057543_01.jpg', 'KakaoTalk_20220928_200057543_08.jpg', 'KakaoTalk_20220928_200057543_09.jpg', 'KakaoTalk_20220928_200057543_10.jpg', 'KakaoTalk_20220928_200057543_11.jpg', 'KakaoTalk_20220928_200057543_12.jpg', 'KakaoTalk_20220928_200057543_13.jpg', 'KakaoTalk_20220928_200057543_14.jpg', 'KakaoTalk_20220928_200057543_15.jpg', 'KakaoTalk_20220928_200057543_16.jpg', 'KakaoTalk_20220928_200057543_17.jpg', 'KakaoTalk_20220928_200057543_18.jpg', 'KakaoTalk_20220928_200057543_19.jpg', 'KakaoTalk_20220928_200057543_20.jpg', 'KakaoTalk_20220928_200057543_21.jpg', 'KakaoTalk_20220928_200057543_22.jpg', 'KakaoTalk_20220928_200057543_23.jpg', 'KakaoTalk_20220928_200057543_24.jpg', 'KakaoTalk_20220928_200057543_25.jpg', 'KakaoTalk_20220928_200057543_26.jpg', 'KakaoTalk_20220928_200057543_27.jpg', 'KakaoTalk_20220928_200057543_28.jpg', 'KakaoTalk_20220928_200057543_29.jpg', 'KakaoTalk_20220928_211458484.jpg', 'KakaoTalk_20220928_211458484_01.jpg', 'KakaoTalk_20220928_211458484_02.jpg', 'KakaoTalk_20220928_211458484_03.jpg', 'KakaoTalk_20220928_211458484_04.jpg', 'KakaoTalk_20220928_211458484_05.jpg', 'KakaoTalk_20221006_164508128_09.jpg', 'KakaoTalk_20221006_164508128_10.jpg', 'KakaoTalk_20221006_164508128_11.jpg', 'KakaoTalk_20221006_164508128_12.jpg', 'KakaoTalk_20221006_164508128_13.jpg', 'KakaoTalk_20221006_164508128_14.jpg', 'KakaoTalk_20221006_164508128_15.jpg', 'KakaoTalk_20221006_164508128_16.jpg', 'KakaoTalk_20221006_164508128_18.jpg', 'KakaoTalk_20221006_164508128_19.jpg']
# ['KakaoTalk_20221006_155319782.jpg', 'KakaoTalk_20221006_155319782_01.jpg', 'KakaoTalk_20221006_155319782_02.jpg', 'KakaoTalk_20221006_155319782_03.jpg', 'KakaoTalk_20221006_155319782_04.jpg', 'KakaoTalk_20221006_155319782_05.jpg', 'KakaoTalk_20221006_155319782_06.jpg', 'KakaoTalk_20221006_155319782_07.jpg', 'KakaoTalk_20221006_155319782_08.jpg', 'KakaoTalk_20221006_155319782_09.jpg', 'KakaoTalk_20221006_155319782_10.jpg', 'KakaoTalk_20221006_155319782_11.jpg', 'KakaoTalk_20221006_155319782_12.jpg', 'KakaoTalk_20221006_155319782_13.jpg', 'KakaoTalk_20221006_155319782_14.jpg', 'KakaoTalk_20221006_155319782_15.jpg', 'KakaoTalk_20221006_155319782_16.jpg', 'KakaoTalk_20221006_155319782_17.jpg', 'KakaoTalk_20221006_155319782_18.jpg', 'KakaoTalk_20221006_155319782_19.jpg', 'KakaoTalk_20221006_155319782_20.jpg', 'KakaoTalk_20221006_155319782_21.jpg', 'KakaoTalk_20221006_155319782_22.jpg', 'KakaoTalk_20221006_155319782_23.jpg', 'KakaoTalk_20221006_155319782_24.jpg', 'KakaoTalk_20221006_155319782_25.jpg', 'KakaoTalk_20221006_155319782_26.jpg', 'KakaoTalk_20221006_155319782_27.jpg', 'KakaoTalk_20221006_155319782_28.jpg', 'KakaoTalk_20221006_155319782_29.jpg', 'KakaoTalk_20221006_161612812.jpg', 'KakaoTalk_20221006_161612812_01.jpg', 'KakaoTalk_20221006_161612812_02.jpg', 'KakaoTalk_20221006_161612812_03.jpg', 'KakaoTalk_20221006_161612812_04.jpg', 'KakaoTalk_20221006_161612812_05.jpg', 'KakaoTalk_20221006_161612812_06.jpg', 'KakaoTalk_20221006_161612812_07.jpg', 'KakaoTalk_20221006_161612812_08.jpg', 'KakaoTalk_20221006_161612812_09.jpg']

# %%
print('Total training normal images :',len(os.listdir(train_normal_dir)))
print('Total training adnormal images :',len(os.listdir(train_adnormal_dir)))

print('Total validation normal images :',len(os.listdir(validation_normal_dir)))
print('Total validation adnormal images :',len(os.listdir(validation_adnormal_dir)))

print('Total test normal images :',len(os.listdir(test_normal_dir)))
print('Total test adnormal images :',len(os.listdir(test_adnormal_dir)))
# Out:
# Total training normal images : 40
# Total training adnormal images : 40
# Total validation normal images : 10
# Total validation adnormal images : 10
# Total test normal images : 5
# Total test adnormal images : 5

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows,ncols=4,4
pic_index=0

fig=plt.gcf()
fig.set_size_inches(ncols*3,nrows*3)


pic_index+=8

next_normal_pix=[os.path.join(train_normal_dir,fname) for fname in train_normal_fnames[pic_index-8:pic_index]]
next_adnormal_pix=[os.path.join(train_adnormal_dir,fname) for fname in train_adnormal_fnames[pic_index-8:pic_index]]


for i, img_path in enumerate(next_normal_pix+next_adnormal_pix):
    sp=plt.subplot(nrows,ncols,i+1)
    sp.axis('OFF')
    
    img=mpimg.imread(img_path)
    plt.imshow(img)
    
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
train_datagen=ImageDataGenerator(rescale=1./255,
                                 rotation_range=2,
                                 #width_shift_range = 0.2,
                                 #height_shift_range = 0.4,
                                 #shear_range = 0.2,
                                 #zoom_range = 0.2,
                                 horizontal_flip=False,
                                 vertical_flip=False,
                                 fill_mode='nearest'
                                 )



validation_datagen=ImageDataGenerator(rescale=1./255)
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=20,
                                                    color_mode='grayscale',
                                                    class_mode='binary',
                                                    target_size=(256,256))

validation_generator=validation_datagen.flow_from_directory(validation_dir,
                                                            batch_size=4,
                                                            color_mode='grayscale',
                                                            class_mode='binary',
                                                            target_size=(256,256))




test_generator=test_datagen.flow_from_directory(test_dir,
                                                batch_size=4,
                                                color_mode='grayscale',
                                                class_mode='binary',
                                                target_size=(256,256))
# Out:
# Found 80 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.
# Found 10 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'adnormal': 0, 'normal': 1}

# %%
sample_img=mpimg.imread(next_normal_pix[0])
plt.imshow(sample_img)
plt.show()

# %%
sample_img=mpimg.imread(next_adnormal_pix[0])
plt.imshow(sample_img)
plt.show()

# %%
max_iter=10
cnt=1
sample_img2=sample_img[np.newaxis, ...]


plt.figure(figsize=(30,30))
for img in train_datagen.flow(sample_img2):
    plt.subplot(1,max_iter,cnt)
    plt.imshow(image.array_to_img(img[0]))
    
    if cnt == max_iter:
        break
    cnt+=1

# %%
import tensorflow as tf
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Conv2D(64, (2, 2), activation='relu',
                        input_shape=(256, 256, 1)))
model.add(layers.MaxPooling2D((3, 3)))
model.add(layers.Conv2D(64, (2, 2), activation='relu'))
model.add(layers.MaxPooling2D((3, 3)))
model.add(layers.Conv2D(32, (2, 2), activation='relu'))
model.add(layers.MaxPooling2D((3,3)))
model.add(layers.Conv2D(128, (2, 2), activation='relu'))
model.add(layers.MaxPooling2D((3, 3)))
model.add(layers.Dropout(0.2))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 255, 255, 64)      320
#
#  max_pooling2d (MaxPooling2D  (None, 85, 85, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 84, 84, 64)        16448
#
#  max_pooling2d_1 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 27, 27, 32)        8224
#
#  max_pooling2d_2 (MaxPooling  (None, 9, 9, 32)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 128)         16512
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  dropout (Dropout)           (None, 2, 2, 128)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 304,673
# Trainable params: 304,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
import math
import time
import datetime

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 733181279897075639
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 9927917568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 41679778692389527
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
start=datetime.datetime.now()

history=model.fit(train_generator,
                  validation_data=validation_generator,
                  steps_per_epoch=2,
                  epochs=100,
                  validation_steps=2,
                  verbose=2)

end=datetime.datetime.now()
time=end-start
print("model fit time",time)
# Out:
# Epoch 1/100
# 2/2 - 3s - loss: 0.7231 - accuracy: 0.5500 - val_loss: 0.6904 - val_accuracy: 0.5000 - 3s/epoch - 1s/step
# Epoch 2/100
# 2/2 - 0s - loss: 0.7201 - accuracy: 0.5750 - val_loss: 0.6912 - val_accuracy: 0.5000 - 282ms/epoch - 141ms/step
# Epoch 3/100
# 2/2 - 0s - loss: 0.6986 - accuracy: 0.4750 - val_loss: 0.6888 - val_accuracy: 0.5000 - 295ms/epoch - 148ms/step
# Epoch 4/100
# 2/2 - 0s - loss: 0.6907 - accuracy: 0.5500 - val_loss: 0.6842 - val_accuracy: 1.0000 - 312ms/epoch - 156ms/step
# Epoch 5/100
# 2/2 - 0s - loss: 0.6799 - accuracy: 0.7250 - val_loss: 0.7219 - val_accuracy: 0.3750 - 317ms/epoch - 158ms/step
# Epoch 6/100
# 2/2 - 0s - loss: 0.6849 - accuracy: 0.6000 - val_loss: 0.6651 - val_accuracy: 1.0000 - 308ms/epoch - 154ms/step
# Epoch 7/100
# 2/2 - 0s - loss: 0.6671 - accuracy: 0.7500 - val_loss: 0.6569 - val_accuracy: 1.0000 - 317ms/epoch - 158ms/step
# Epoch 8/100
# 2/2 - 0s - loss: 0.5929 - accuracy: 0.8250 - val_loss: 0.5040 - val_accuracy: 0.7500 - 333ms/epoch - 166ms/step
# Epoch 9/100
# 2/2 - 0s - loss: 0.6780 - accuracy: 0.5250 - val_loss: 0.6255 - val_accuracy: 0.8750 - 365ms/epoch - 183ms/step
# Epoch 10/100
# 2/2 - 0s - loss: 0.6141 - accuracy: 0.8750 - val_loss: 0.6013 - val_accuracy: 0.5000 - 270ms/epoch - 135ms/step
# Epoch 11/100
# 2/2 - 0s - loss: 0.6137 - accuracy: 0.5750 - val_loss: 0.5313 - val_accuracy: 0.8750 - 275ms/epoch - 137ms/step
# Epoch 12/100
# 2/2 - 0s - loss: 0.5118 - accuracy: 0.7500 - val_loss: 0.4939 - val_accuracy: 0.5000 - 275ms/epoch - 137ms/step
# Epoch 13/100
# 2/2 - 0s - loss: 0.4233 - accuracy: 0.8250 - val_loss: 1.2771 - val_accuracy: 0.2500 - 273ms/epoch - 137ms/step
# Epoch 14/100
# 2/2 - 0s - loss: 0.3277 - accuracy: 0.8750 - val_loss: 0.3420 - val_accuracy: 0.7500 - 277ms/epoch - 138ms/step
# Epoch 15/100
# 2/2 - 0s - loss: 0.6780 - accuracy: 0.7000 - val_loss: 0.2705 - val_accuracy: 1.0000 - 282ms/epoch - 141ms/step
# Epoch 16/100
# 2/2 - 0s - loss: 0.3717 - accuracy: 0.9250 - val_loss: 0.3123 - val_accuracy: 1.0000 - 277ms/epoch - 139ms/step
# Epoch 17/100
# 2/2 - 0s - loss: 0.2479 - accuracy: 1.0000 - val_loss: 0.2207 - val_accuracy: 1.0000 - 273ms/epoch - 137ms/step
# Epoch 18/100
# 2/2 - 0s - loss: 0.1965 - accuracy: 0.9750 - val_loss: 0.2100 - val_accuracy: 0.8750 - 288ms/epoch - 144ms/step
# Epoch 19/100
# 2/2 - 0s - loss: 0.2146 - accuracy: 0.9750 - val_loss: 0.2064 - val_accuracy: 0.8750 - 273ms/epoch - 137ms/step
# Epoch 20/100
# 2/2 - 0s - loss: 0.1788 - accuracy: 0.9750 - val_loss: 0.2010 - val_accuracy: 1.0000 - 273ms/epoch - 136ms/step
# Epoch 21/100
# 2/2 - 0s - loss: 0.1308 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 1.0000 - 282ms/epoch - 141ms/step
# Epoch 22/100
# 2/2 - 0s - loss: 0.0660 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 1.0000 - 278ms/epoch - 139ms/step
# Epoch 23/100
# 2/2 - 0s - loss: 0.0746 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 1.0000 - 274ms/epoch - 137ms/step
# Epoch 24/100
# 2/2 - 0s - loss: 0.0500 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 1.0000 - 288ms/epoch - 144ms/step
# Epoch 25/100
# 2/2 - 0s - loss: 0.1713 - accuracy: 0.9250 - val_loss: 0.2654 - val_accuracy: 1.0000 - 284ms/epoch - 142ms/step
# Epoch 26/100
# 2/2 - 0s - loss: 0.1491 - accuracy: 0.9250 - val_loss: 0.0627 - val_accuracy: 1.0000 - 276ms/epoch - 138ms/step
# Epoch 27/100
# 2/2 - 0s - loss: 0.0427 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 1.0000 - 276ms/epoch - 138ms/step
# Epoch 28/100
# 2/2 - 0s - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000 - 281ms/epoch - 140ms/step
# Epoch 29/100
# 2/2 - 0s - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000 - 280ms/epoch - 140ms/step
# Epoch 30/100
# 2/2 - 0s - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000 - 281ms/epoch - 140ms/step
# Epoch 31/100
# 2/2 - 0s - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 1.0000 - 281ms/epoch - 140ms/step
# Epoch 32/100
# 2/2 - 0s - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000 - 276ms/epoch - 138ms/step
# Epoch 33/100
# 2/2 - 0s - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000 - 279ms/epoch - 139ms/step
# Epoch 34/100
# 2/2 - 0s - loss: 0.0308 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.8750 - 279ms/epoch - 140ms/step
# Epoch 35/100
# 2/2 - 0s - loss: 0.0373 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 1.0000 - 278ms/epoch - 139ms/step
# Epoch 36/100
# 2/2 - 0s - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000 - 275ms/epoch - 137ms/step
# Epoch 37/100
# 2/2 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 1.0000 - 278ms/epoch - 139ms/step
# Epoch 38/100
# 2/2 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 1.0000 - 277ms/epoch - 139ms/step
# Epoch 39/100
# 2/2 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 1.0000 - 288ms/epoch - 144ms/step
# Epoch 40/100
# 2/2 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - 286ms/epoch - 143ms/step
# Epoch 41/100
# 2/2 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000 - 275ms/epoch - 138ms/step
# Epoch 42/100
# 2/2 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000 - 283ms/epoch - 142ms/step
# Epoch 43/100
# 2/2 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 1.0000 - 279ms/epoch - 140ms/step
# Epoch 44/100
# 2/2 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 3.9256e-04 - val_accuracy: 1.0000 - 281ms/epoch - 141ms/step
# Epoch 45/100
# 2/2 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000 - 290ms/epoch - 145ms/step
# Epoch 46/100
# 2/2 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - 277ms/epoch - 138ms/step
# Epoch 47/100
# 2/2 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - 282ms/epoch - 141ms/step
# Epoch 48/100
# 2/2 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 1.0000 - 288ms/epoch - 144ms/step
# Epoch 49/100
# 2/2 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.4039e-04 - val_accuracy: 1.0000 - 293ms/epoch - 146ms/step
# Epoch 50/100
# 2/2 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.8634e-04 - val_accuracy: 1.0000 - 290ms/epoch - 145ms/step
# Epoch 51/100
# 2/2 - 0s - loss: 5.2823e-04 - accuracy: 1.0000 - val_loss: 8.7613e-04 - val_accuracy: 1.0000 - 281ms/epoch - 140ms/step
# Epoch 52/100
# 2/2 - 0s - loss: 8.6855e-04 - accuracy: 1.0000 - val_loss: 4.4592e-04 - val_accuracy: 1.0000 - 292ms/epoch - 146ms/step
# Epoch 53/100
# 2/2 - 0s - loss: 8.9340e-04 - accuracy: 1.0000 - val_loss: 3.8398e-04 - val_accuracy: 1.0000 - 275ms/epoch - 137ms/step
# Epoch 54/100
# 2/2 - 0s - loss: 5.1344e-04 - accuracy: 1.0000 - val_loss: 6.9377e-04 - val_accuracy: 1.0000 - 283ms/epoch - 142ms/step
# Epoch 55/100
# 2/2 - 0s - loss: 4.9313e-04 - accuracy: 1.0000 - val_loss: 6.6450e-04 - val_accuracy: 1.0000 - 276ms/epoch - 138ms/step
# Epoch 56/100
# 2/2 - 0s - loss: 2.6855e-04 - accuracy: 1.0000 - val_loss: 3.7598e-05 - val_accuracy: 1.0000 - 276ms/epoch - 138ms/step
# Epoch 57/100
# 2/2 - 0s - loss: 6.2198e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - 271ms/epoch - 136ms/step
# Epoch 58/100
# 2/2 - 0s - loss: 1.1287 - accuracy: 0.8000 - val_loss: 0.0549 - val_accuracy: 1.0000 - 280ms/epoch - 140ms/step
# Epoch 59/100
# 2/2 - 0s - loss: 0.0714 - accuracy: 0.9750 - val_loss: 2.1577e-04 - val_accuracy: 1.0000 - 280ms/epoch - 140ms/step
# Epoch 60/100
# 2/2 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000 - 284ms/epoch - 142ms/step
# Epoch 61/100
# 2/2 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000 - 284ms/epoch - 142ms/step
# Epoch 62/100
# 2/2 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.1950e-04 - val_accuracy: 1.0000 - 283ms/epoch - 141ms/step
# Epoch 63/100
# 2/2 - 0s - loss: 8.5956e-04 - accuracy: 1.0000 - val_loss: 9.8203e-04 - val_accuracy: 1.0000 - 278ms/epoch - 139ms/step
# Epoch 64/100
# 2/2 - 0s - loss: 6.7705e-04 - accuracy: 1.0000 - val_loss: 4.4783e-04 - val_accuracy: 1.0000 - 283ms/epoch - 141ms/step
# Epoch 65/100
# 2/2 - 0s - loss: 8.3201e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - 285ms/epoch - 143ms/step
# Epoch 66/100
# 2/2 - 0s - loss: 5.1355e-04 - accuracy: 1.0000 - val_loss: 8.9873e-04 - val_accuracy: 1.0000 - 282ms/epoch - 141ms/step
# Epoch 67/100
# 2/2 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.9622e-04 - val_accuracy: 1.0000 - 277ms/epoch - 138ms/step
# Epoch 68/100
# 2/2 - 0s - loss: 5.9701e-04 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000 - 286ms/epoch - 143ms/step
# Epoch 69/100
# 2/2 - 0s - loss: 6.8241e-04 - accuracy: 1.0000 - val_loss: 7.1488e-04 - val_accuracy: 1.0000 - 286ms/epoch - 143ms/step
# Epoch 70/100
# 2/2 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000 - 281ms/epoch - 140ms/step
# Epoch 71/100
# 2/2 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.8831e-04 - val_accuracy: 1.0000 - 284ms/epoch - 142ms/step
# Epoch 72/100
# 2/2 - 0s - loss: 8.4807e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 286ms/epoch - 143ms/step
# Epoch 73/100
# 2/2 - 0s - loss: 4.6290e-04 - accuracy: 1.0000 - val_loss: 4.4389e-04 - val_accuracy: 1.0000 - 288ms/epoch - 144ms/step
# Epoch 74/100
# 2/2 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000 - 283ms/epoch - 141ms/step
# Epoch 75/100
# 2/2 - 0s - loss: 7.0144e-04 - accuracy: 1.0000 - val_loss: 4.4798e-04 - val_accuracy: 1.0000 - 289ms/epoch - 145ms/step
# Epoch 76/100
# 2/2 - 0s - loss: 6.9091e-04 - accuracy: 1.0000 - val_loss: 5.5940e-05 - val_accuracy: 1.0000 - 275ms/epoch - 137ms/step
# Epoch 77/100
# 2/2 - 0s - loss: 1.7208e-04 - accuracy: 1.0000 - val_loss: 1.3154e-04 - val_accuracy: 1.0000 - 284ms/epoch - 142ms/step
# Epoch 78/100
# 2/2 - 0s - loss: 7.6191e-04 - accuracy: 1.0000 - val_loss: 1.1425e-04 - val_accuracy: 1.0000 - 280ms/epoch - 140ms/step
# Epoch 79/100
# 2/2 - 0s - loss: 3.3327e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - 291ms/epoch - 146ms/step
# Epoch 80/100
# 2/2 - 0s - loss: 1.9132e-04 - accuracy: 1.0000 - val_loss: 3.0337e-04 - val_accuracy: 1.0000 - 310ms/epoch - 155ms/step
# Epoch 81/100
# 2/2 - 0s - loss: 4.7839e-04 - accuracy: 1.0000 - val_loss: 1.4107e-04 - val_accuracy: 1.0000 - 277ms/epoch - 139ms/step
# Epoch 82/100
# 2/2 - 0s - loss: 4.7978e-04 - accuracy: 1.0000 - val_loss: 6.7672e-05 - val_accuracy: 1.0000 - 293ms/epoch - 147ms/step
# Epoch 83/100
# 2/2 - 0s - loss: 5.2210e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - 284ms/epoch - 142ms/step
# Epoch 84/100
# 2/2 - 0s - loss: 4.4711e-04 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000 - 282ms/epoch - 141ms/step
# Epoch 85/100
# 2/2 - 0s - loss: 2.4751e-04 - accuracy: 1.0000 - val_loss: 7.7002e-05 - val_accuracy: 1.0000 - 287ms/epoch - 143ms/step
# Epoch 86/100
# 2/2 - 0s - loss: 1.9820e-04 - accuracy: 1.0000 - val_loss: 2.8841e-04 - val_accuracy: 1.0000 - 271ms/epoch - 135ms/step
# Epoch 87/100
# 2/2 - 0s - loss: 6.7759e-04 - accuracy: 1.0000 - val_loss: 3.4086e-05 - val_accuracy: 1.0000 - 280ms/epoch - 140ms/step
# Epoch 88/100
# 2/2 - 0s - loss: 1.1309e-04 - accuracy: 1.0000 - val_loss: 1.2516e-04 - val_accuracy: 1.0000 - 279ms/epoch - 140ms/step
# Epoch 89/100
# 2/2 - 0s - loss: 2.2001e-04 - accuracy: 1.0000 - val_loss: 3.3207e-05 - val_accuracy: 1.0000 - 280ms/epoch - 140ms/step
# Epoch 90/100
# 2/2 - 0s - loss: 3.2396e-04 - accuracy: 1.0000 - val_loss: 2.6640e-04 - val_accuracy: 1.0000 - 282ms/epoch - 141ms/step
# Epoch 91/100
# 2/2 - 0s - loss: 1.9169e-05 - accuracy: 1.0000 - val_loss: 5.9319e-04 - val_accuracy: 1.0000 - 286ms/epoch - 143ms/step
# Epoch 92/100
# 2/2 - 0s - loss: 2.8337e-04 - accuracy: 1.0000 - val_loss: 1.8223e-04 - val_accuracy: 1.0000 - 278ms/epoch - 139ms/step
# Epoch 93/100
# 2/2 - 0s - loss: 3.5320e-04 - accuracy: 1.0000 - val_loss: 4.4511e-04 - val_accuracy: 1.0000 - 278ms/epoch - 139ms/step
# Epoch 94/100
# 2/2 - 0s - loss: 6.2478e-05 - accuracy: 1.0000 - val_loss: 2.2723e-05 - val_accuracy: 1.0000 - 280ms/epoch - 140ms/step
# Epoch 95/100
# 2/2 - 0s - loss: 3.5256e-05 - accuracy: 1.0000 - val_loss: 1.5923e-05 - val_accuracy: 1.0000 - 279ms/epoch - 140ms/step
# Epoch 96/100
# 2/2 - 0s - loss: 2.8003e-05 - accuracy: 1.0000 - val_loss: 1.7235e-04 - val_accuracy: 1.0000 - 281ms/epoch - 141ms/step
# Epoch 97/100
# 2/2 - 0s - loss: 6.1805e-05 - accuracy: 1.0000 - val_loss: 3.5960e-06 - val_accuracy: 1.0000 - 285ms/epoch - 143ms/step
# Epoch 98/100
# 2/2 - 0s - loss: 2.7207e-05 - accuracy: 1.0000 - val_loss: 2.6327e-04 - val_accuracy: 1.0000 - 289ms/epoch - 145ms/step
# Epoch 99/100
# 2/2 - 0s - loss: 5.1582e-05 - accuracy: 1.0000 - val_loss: 3.6507e-04 - val_accuracy: 1.0000 - 285ms/epoch - 142ms/step
# Epoch 100/100
# 2/2 - 0s - loss: 1.7602e-04 - accuracy: 1.0000 - val_loss: 6.6433e-05 - val_accuracy: 1.0000 - 287ms/epoch - 143ms/step
# model fit time 0:00:33.423908

# %%
score=model.evaluate(train_generator)
print("accuracy=",score[1])
print("loss=",score[0])
# Out:
# 4/4 [==============================] - 0s 98ms/step - loss: 1.6290e-04 - accuracy: 1.0000
# accuracy= 1.0
# loss= 0.00016289834456983954

# %%
score2=model.evaluate(validation_generator)
print("accuracy=",score2[1])
print("loss=",score2[0])
# Out:
# 5/5 [==============================] - 0s 9ms/step - loss: 3.3148e-04 - accuracy: 1.0000
# accuracy= 1.0
# loss= 0.00033147932845167816

# %%
acc = history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

plt.plot(epochs,acc,'r',label='Training accuracy')
plt.plot(epochs,val_acc,'b',label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()

plt.figure()

plt.plot(epochs,loss,'r',label='Training loss')
plt.plot(epochs,val_loss,'g',label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()

plt.show()

# %%
start = datetime.datetime.now()
score2=model.evaluate(test_generator)
print("accuracy=",score2[1])
print("loss=",score2[0])
end = datetime.datetime.now()
time=end-start
print("test evaluation time",time)
# Out:
# 3/3 [==============================] - 0s 62ms/step - loss: 3.2028 - accuracy: 0.5000
# accuracy= 0.5
# loss= 3.2027575969696045
# test evaluation time 0:00:00.201118

# %%
import numpy as np
from keras.preprocessing import image

test_dir='C:/Data/switch_detection/test/'
test_normal_dir=os.path.join(test_dir,'normal/')
test_normal_filenames=os.listdir(test_normal_dir)
test_normal_filenames


test_adnormal_dir=os.path.join(test_dir,'adnormal/')
test_adnormal_filenames=os.listdir(test_adnormal_dir)
test_adnormal_filenames

dic_screw_filenames={}
dic_screw_filenames['normal']=test_normal_filenames
dic_screw_filenames['adnormal']=test_adnormal_filenames

# %%
for screw,filenames in dic_screw_filenames.items():
    fig=plt.figure(figsize=(16,10))
    rows,cols=1,15
    for i,fn in enumerate(filenames):
        path=test_dir+screw+'/'+fn
        test_img=image.load_img(path,color_mode='grayscale',target_size=(256,256),interpolation='bilinear')
        x=image.img_to_array(test_img)
        x=np.expand_dims(x,axis=0)
        images=np.vstack([x])
        
        
        classes=model.predict(images,batch_size=10)
        print(classes)
        fig.add_subplot(rows,cols,i+1)
        if classes==1:
            plt.title(fn+" is normal")
            plt.axis('off')
            plt.imshow(test_img,cmap='gray')
            
        else:
            plt.title(fn+" is adnormal")
            plt.axis('off')
            plt.imshow(test_img,cmap='gray')
        plt.show();
# Out:
# [[1.]]
# [[0.999997]]
# [[0.98450583]]
# [[1.]]
# [[1.]]
# [[0.]]
# [[0.]]
# [[0.]]
# [[0.]]
# [[0.]]
